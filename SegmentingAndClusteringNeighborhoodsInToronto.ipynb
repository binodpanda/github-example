# %% [markdown]
# ## <center><u>Segmenting and Clustering Neighborhoods in Toronto</u></center>

# %% [markdown]
# #### Question 1:
# 1. Start by creating a new Notebook for this assignment.
# ##### Note book created
#
#
# Import the libraries

# %%
import numpy as np 
import pandas as pd 
import requests # Library for web scraping
print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# #### Question 2:
# 2. Scrap the webpage

# %% [markdown]
# <u>Import the BeautifulSoup and other libraries</u>

# %%
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup
import ssl
import csv

print('BeautifulSoup  & csv imported.')
# Out:
# BeautifulSoup  & csv imported.

# %% [markdown]
# <u>Scrap the webpage</u>

# %%
source = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(source, 'lxml')
print('soup ready')
# Out:
# soup ready

# %% [markdown]
# <u>Scrap and print the data header</u>

# %%
table = soup.find('table',{'class':'wikitable sortable'})
table_rows = table.find_all('tr')

data = []
for row in table_rows:
    data.append([t.text.strip() for t in row.find_all('td')])

df = pd.DataFrame(data, columns=['PostalCode', 'Borough', 'Neighbourhood'])
df = df[~df['PostalCode'].isnull()] #to remove records having postal code null
df.head()
# Out:
#   PostalCode           Borough               Neighbourhood
# 1        M1A      Not assigned
# 2        M2A      Not assigned
# 3        M3A        North York                   Parkwoods
# 4        M4A        North York            Victoria Village
# 5        M5A  Downtown Toronto  Regent Park / Harbourfront

# %% [markdown]
# #### Question 3:
# 3.1. The dataframe will consist of three columns: PostalCode, Borough, and Neighborhood

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 180 entries, 1 to 180
# Data columns (total 3 columns):
# PostalCode       180 non-null object
# Borough          180 non-null object
# Neighbourhood    180 non-null object
# dtypes: object(3)
# memory usage: 5.6+ KB

# %%
df.shape
# Out:
# (180, 3)

# %%
import pandas
import requests
from bs4 import BeautifulSoup
website_text = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(website_text,'lxml')

table = soup.find('table',{'class':'wikitable sortable'})
table_rows = table.find_all('tr')

data = []
for row in table_rows:
    data.append([t.text.strip() for t in row.find_all('td')])

df = pandas.DataFrame(data, columns=['PostalCode', 'Borough', 'Neighbourhood'])
df = df[~df['PostalCode'].isnull()]  

df.head()
# Out:
#   PostalCode           Borough               Neighbourhood
# 1        M1A      Not assigned
# 2        M2A      Not assigned
# 3        M3A        North York                   Parkwoods
# 4        M4A        North York            Victoria Village
# 5        M5A  Downtown Toronto  Regent Park / Harbourfront

# %% [markdown]
# #### Question 3:
# 3.2. Ignore cells with a borough that is Not assigned.

# %%
df.drop(df[df['Borough']=="Not assigned"].index,axis=0, inplace=True)
df1 = df.reset_index()
df1.head()
# Out:
#    index PostalCode           Borough  \
# 0      3        M3A        North York
# 1      4        M4A        North York
# 2      5        M5A  Downtown Toronto
# 3      6        M6A        North York
# 4      7        M7A  Downtown Toronto
#
#                                   Neighbourhood
# 0                                     Parkwoods
# 1                              Victoria Village
# 2                    Regent Park / Harbourfront
# 3             Lawrence Manor / Lawrence Heights
# 4  Queen's Park / Ontario Provincial Government

# %%
df2= df1.groupby('PostalCode').agg(lambda x: ','.join(x))
df2.head()
# Out:
#                 Borough                             Neighbourhood
# PostalCode
# M1B         Scarborough                           Malvern / Rouge
# M1C         Scarborough  Rouge Hill / Port Union / Highland Creek
# M1E         Scarborough       Guildwood / Morningside / West Hill
# M1G         Scarborough                                    Woburn
# M1H         Scarborough                                 Cedarbrae

# %%
df2.shape
# Out:
# (103, 2)

# %%
df2.loc[df2['Neighbourhood']=="Not assigned",'Neighbourhood']=df2.loc[df2['Neighbourhood']=="Not assigned",'Borough']
df3 = df2.reset_index()

# %%
df3['Borough']= df3['Borough'].str.replace('nan|[{}\s]','').str.split(',').apply(set).str.join(',').str.strip(',').str.replace(",{2,}",",")
df3.head()
# Out:
#   PostalCode      Borough                             Neighbourhood
# 0        M1B  Scarborough                           Malvern / Rouge
# 1        M1C  Scarborough  Rouge Hill / Port Union / Highland Creek
# 2        M1E  Scarborough       Guildwood / Morningside / West Hill
# 3        M1G  Scarborough                                    Woburn
# 4        M1H  Scarborough                                 Cedarbrae
